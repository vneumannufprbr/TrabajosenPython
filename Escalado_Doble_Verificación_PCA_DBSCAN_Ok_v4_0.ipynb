# %% [markdown]
# <a href="https://colab.research.google.com/github/vneumannufprbr/TrabajosenPython/blob/main/Escalado_Doble_Verificaci%C3%B3n_PCA_DBSCAN_Ok_v4_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================================================
# Celda 1: Importación de Librerías y Carga de Datos
# ==============================================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
import warnings

# --- Configuraciones ---
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (18, 6)
warnings.filterwarnings('ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None #

# --- Carga de Datos ---
try:
    file_path = 'datos_fusionados_operantes.xlsx'
    df_sensores = pd.read_excel(file_path)
    # Asegurarse de que la fecha sea el índice y esté en formato datetime
    if 'fecha' in df_sensores.columns:
        df_sensores['fecha'] = pd.to_datetime(df_sensores['fecha'])
        df_sensores.set_index('fecha', inplace=True)
    print("Archivo 'datos_fusionados_operantes.xlsx' cargado exitosamente.")
    print(f"El dataset tiene {df_sensores.shape[0]} filas y {df_sensores.shape[1]} columnas.")
except FileNotFoundError:
    print(f"Error: El archivo '{file_path}' no se encontró.")
    print("Por favor, sube el archivo al explorador de archivos de Colab y vuelve a ejecutar esta celda.")
except Exception as e:
    print(f"Ocurrió un error al leer el archivo: {e}")

# ==============================================================================
# Celda 2: Verificación Temporal con PCA (Escalado por Etiqueta Padre)
# ==============================================================================
print("--- Iniciando Verificación Temporal con PCA para cada 'etiqueta_padre' ---")

# Conjunto para almacenar todas las fechas identificadas como anómalas por PCA
pca_anomalies_indices = set()
# DataFrame para almacenar todos los errores de reconstrucción
all_reconstruction_errors = pd.DataFrame()

# Limpiar espacios en blanco de 'etiqueta_padre' antes de obtener los valores únicos
df_sensores['etiqueta_padre'] = df_sensores['etiqueta_padre'].str.strip()
parent_labels = df_sensores['etiqueta_padre'].dropna().unique()

# --- Multiplicador para el umbral MAD (ajustable) ---
mad_multiplier = 13527.37 # LO NORMAL ES DE 2 A 6, PERO EN FUNCIÓN A LA MAGNITUD DE
# LOS errores de reconstrucción, SE PUEDE CAMBIAR A VALORES MÁS ALTOS O BAJOS
# PARA AJUSTAR LA SENSIBILIDAD DEL UMBRAL

for i, label in enumerate(parent_labels):
    print(f"Procesando grupo {i+1}/{len(parent_labels)}: {label}")
    df_grupo = df_sensores[df_sensores['etiqueta_padre'] == label]

    # Seleccionar solo columnas numéricas relevantes para este grupo
    numeric_cols = df_grupo.select_dtypes(include=np.number).columns.tolist()
    # Excluir columnas que no son mediciones directas o tienen muchos nulos
    cols_to_exclude = ['coordenada_norte', 'coordenada_este', 'Elevación', 'nivel_embalse'] #
    numeric_cols = [col for col in numeric_cols if col not in cols_to_exclude and df_grupo[col].nunique() > 1]

    if len(numeric_cols) < 2:
        print(f"  -> Grupo omitido: no tiene suficientes columnas numéricas ({len(numeric_cols)}).")
        continue

    # Preparar datos para PCA
    df_numeric = df_grupo[numeric_cols].dropna()

    if len(df_numeric) < 5:
        print(f"  -> Grupo omitido: no tiene suficientes datos ({len(df_numeric)} filas).")
        continue

    # Escalar y aplicar PCA
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_numeric)
    pca = PCA(n_components=0.95) # Retener 95% de la varianza
    transformed_data = pca.fit_transform(scaled_data)
    reconstructed_data = pca.inverse_transform(transformed_data)

    # Calcular error de reconstrucción
    reconstruction_error = np.mean((scaled_data - reconstructed_data)**2, axis=1)
    df_error = pd.DataFrame({'reconstruction_error': reconstruction_error}, index=df_numeric.index)

    # Almacenar errores de reconstrucción para análisis posterior
    all_reconstruction_errors = pd.concat([all_reconstruction_errors, df_error])

    # Umbral de anomalía robusto con MAD (Median Absolute Deviation)
    median_error = df_error['reconstruction_error'].median()
    mad_error = np.median(np.abs(df_error['reconstruction_error'] - median_error))
    threshold_mad = median_error + mad_multiplier * mad_error # Usar el multiplicador

    # Identificar picos y almacenar sus índices
    peak_indices = df_error[df_error['reconstruction_error'] > threshold_mad].index
    pca_anomalies_indices.update(peak_indices)
    print(f"  -> Se encontraron {len(peak_indices)} picos de error de PCA con multiplicador {mad_multiplier}.")

print(f"\nVerificación Temporal completada. Total de fechas únicas con anomalías PCA: {len(pca_anomalies_indices)}")


# ==============================================================================
# Celda 3: Verificación Espacial con DBSCAN (Escalado por Ubicación Geológica)
# ==============================================================================
print("\n--- Iniciando Verificación Espacial con DBSCAN para cada 'local_geologico' ---")

# Conjunto para almacenar todas las fechas identificadas como "ruido" por DBSCAN
dbscan_noise_indices = set()

# Características para el clustering espacial
features_for_dbscan = ['valor_promedio', 'valor_minimo', 'valor_maximo']
df_dbscan_analysis = df_sensores.dropna(subset=features_for_dbscan)

# Limpiar espacios en blanco de 'local_geologico' antes de obtener los valores únicos
df_dbscan_analysis['local_geologico'] = df_dbscan_analysis['local_geologico'].str.strip()
geolocations = df_dbscan_analysis['local_geologico'].dropna().unique()

for i, location in enumerate(geolocations):
    print(f"Procesando ubicación {i+1}/{len(geolocations)}: {location}")
    df_location = df_dbscan_analysis[df_dbscan_analysis['local_geologico'] == location]

    if len(df_location) < 5: # min_samples
        print(f"  -> Ubicación omitida: no tiene suficientes datos.")
        continue

    # Escalar datos
    scaled_data = StandardScaler().fit_transform(df_location[features_for_dbscan])

    # Aplicar DBSCAN
    dbscan = DBSCAN(eps=0.7, min_samples=4)
    labels = dbscan.fit_predict(scaled_data)
    df_location['dbscan_label'] = labels

    # Identificar ruido y almacenar sus índices
    noise_indices = df_location[df_location['dbscan_label'] == -1].index
    dbscan_noise_indices.update(noise_indices)
    print(f"  -> Se encontraron {len(noise_indices)} puntos de ruido.")

print(f"\nVerificación Espacial completada. Total de fechas únicas con ruido DBSCAN: {len(dbscan_noise_indices)}")


# ==============================================================================
# Celda 4: Implementación de la Matriz de Diagnóstico
# ==============================================================================
print("\n--- Aplicando la Matriz de Diagnóstico a todo el dataset ---")

# Definir las categorías
categoria_normal = 'Sistema Normal'
categoria_sensor_defectuoso = 'Sensor Defectuoso'
categoria_anomalia_regional = 'Anomalía Regional'
categoria_anomalia_estructural = 'Anomalía Estructural'

# Función de clasificación optimizada
def classify_observation(date_index):
    is_pca_anomaly = date_index in pca_anomalies_indices
    is_dbscan_noise = date_index in dbscan_noise_indices

    if is_pca_anomaly and is_dbscan_noise:
        return categoria_anomalia_estructural
    elif is_pca_anomaly and not is_dbscan_noise:
        return categoria_sensor_defectuoso
    elif not is_pca_anomaly and is_dbscan_noise:
        return categoria_anomalia_regional
    else:
        return categoria_normal

# Aplicar la clasificación a todo el DataFrame
df_sensores['diagnostic_category'] = [classify_observation(date) for date in df_sensores.index]

print("Clasificación de diagnóstico completada.")


# ==============================================================================
# Celda 5: Análisis y Visualización de Resultados
# ==============================================================================
print("\n=========================================================")
print("      Resultados de la Matriz de Diagnóstico")
print("=========================================================")

# --- Definir paleta de colores personalizada ---
color_map = {
    'Anomalía Estructural': 'red',
    'Anomalía Regional': 'orange',
    'Sensor Defectuoso': 'blue',
    'Sistema Normal': 'green'
}
# Asegurar el orden de las categorías para los gráficos
category_order = list(color_map.keys())

# --- 1.A. Distribución General de Categorías ---
print("\nDistribución General de observaciones por categoría de diagnóstico:")
category_counts = df_sensores['diagnostic_category'].value_counts()
category_percentages = df_sensores['diagnostic_category'].value_counts(normalize=True) * 100
summary_df = pd.DataFrame({'Conteo': category_counts, 'Porcentaje (%)': category_percentages})
display(summary_df)

# --- 1.B. Distribución por Etiqueta Padre ---
print("\n---------------------------------------------------------")
print("      Distribución de Diagnóstico por Etiqueta Padre")
print("---------------------------------------------------------")
# Limpiar espacios en blanco de 'etiqueta_padre' antes de obtener los valores únicos para el resumen
df_sensores['etiqueta_padre'] = df_sensores['etiqueta_padre'].str.strip()
parent_labels_in_results = df_sensores['etiqueta_padre'].dropna().unique()
for label in sorted(parent_labels_in_results):
    print(f"\n--- Resumen para: {label.strip()} ---")
    df_label_specific = df_sensores[df_sensores['etiqueta_padre'] == label]
    label_counts = df_label_specific['diagnostic_category'].value_counts()
    if label_counts.empty:
        print("No hay datos de diagnóstico para este grupo.")
        continue
    label_percentages = df_label_specific['diagnostic_category'].value_counts(normalize=True) * 100
    summary_label_df = pd.DataFrame({'Conteo': label_counts, 'Porcentaje (%)': label_percentages})
    display(summary_label_df)

# --- 2. Visualización: Distribución Temporal (Anual) ---
print("\nGenerando gráfico de distribución anual de categorías...")
df_time_category = df_sensores.groupby([df_sensores.index, 'diagnostic_category']).size().unstack(fill_value=0)
df_time_category_yearly = df_time_category.resample('Y').sum()

# Asegurar que todas las categorías estén presentes y en el orden correcto
for cat in category_order:
    if cat not in df_time_category_yearly.columns:
        df_time_category_yearly[cat] = 0
df_time_category_yearly = df_time_category_yearly[category_order]

plt.figure()
df_time_category_yearly.plot(kind='bar', stacked=True, figsize=(20, 8), color=color_map.values(), width=0.7)
plt.title("Distribución Anual de Categorías de Diagnóstico a lo largo del Tiempo", fontsize=16)
plt.xlabel("Año", fontsize=12)
plt.ylabel("Número de Observaciones", fontsize=12)
plt.legend(title="Categoría de Diagnóstico")
tick_labels = [item.strftime('%Y') for item in df_time_category_yearly.index]
plt.gca().set_xticklabels(tick_labels, rotation=45, ha='right')
plt.tight_layout()
plt.show()

# --- 3. Visualización Detallada: Años con Anomalías Críticas  ---
print("\n---------------------------------------------------------------------")
print("      Análisis Mensual Detallado de Años con Anomalías Críticas (Estructural o Regional)")
print("---------------------------------------------------------------------")

# Identificar años con anomalías Estructurales O Regionales
structural_anomalies_df = df_sensores[df_sensores['diagnostic_category'] == 'Anomalía Estructural']
years_with_structural = structural_anomalies_df.index.year.unique()

regional_anomalies_df = df_sensores[df_sensores['diagnostic_category'] == 'Anomalía Regional']
years_with_regional = regional_anomalies_df.index.year.unique()

# Combinar y obtener una lista única y ordenada de años críticos
critical_years = sorted(list(set(years_with_structural) | set(years_with_regional)))


if not critical_years:
    print("No se encontraron años con 'Anomalía Estructural' o 'Anomalía Regional' para un análisis detallado.")
else:
    for year in critical_years:
        print(f"\nGenerando gráfico mensual para el año: {year}")
        df_year = df_sensores[df_sensores.index.year == year]

        # Agrupar por mes y categoría
        df_monthly = df_year.groupby([df_year.index.month, 'diagnostic_category']).size().unstack(fill_value=0)

        # Asegurar que todas las categorías estén presentes y en el orden correcto
        for cat in category_order:
            if cat not in df_monthly.columns:
                df_monthly[cat] = 0
        df_monthly = df_monthly[category_order]

        plt.figure()
        df_monthly.plot(kind='bar', stacked=True, figsize=(15, 7), color=color_map.values(), width=0.8)
        plt.title(f"Distribución Mensual de Categorías para el Año {year}", fontsize=16)
        plt.xlabel("Mes", fontsize=12)
        plt.ylabel("Número de Observaciones", fontsize=12)
        plt.legend(title="Categoría de Diagnóstico")

        # Nombres de los meses en español para el eje X
        meses = ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic']
        plt.gca().set_xticklabels([meses[i-1] for i in df_monthly.index], rotation=0)
        plt.tight_layout()
        plt.show()

# --- 4. Visualización: Distribución por Etiqueta Padre ---
print("\nGenerando gráfico de distribución por 'etiqueta_padre'...")
# Limpiar espacios en blanco de 'etiqueta_padre' antes de agrupar para el gráfico
df_sensores['etiqueta_padre'] = df_sensores['etiqueta_padre'].str.strip()
df_label_category = df_sensores.groupby(['etiqueta_padre', 'diagnostic_category']).size().unstack(fill_value=0)

# Asegurar que todas las categorías estén presentes y en el orden correcto
for cat in category_order:
    if cat not in df_label_category.columns:
        df_label_category[cat] = 0
df_label_category = df_label_category[category_order]

plt.figure()
df_label_category.plot(kind='bar', stacked=True, figsize=(20, 8), color=color_map.values(), width=0.8)
plt.title("Distribución de Categorías de Diagnóstico por Etiqueta Padre", fontsize=16)
plt.xlabel("Etiqueta Padre", fontsize=12)
plt.ylabel("Número de Observaciones", fontsize=12)
plt.legend(title="Categoría de Diagnóstico")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# --- 5. Guardar resultados ---
output_filename = "matriz_diagnostico_escalada_completa.xlsx"
df_sensores.to_excel(output_filename)
print(f"\nResultados completos guardados en '{output_filename}'")
# Out:
# Archivo 'datos_fusionados_operantes.xlsx' cargado exitosamente.
# El dataset tiene 75566 filas y 30 columnas.
# --- Iniciando Verificación Temporal con PCA para cada 'etiqueta_padre' ---
# Procesando grupo 1/17: EM-E-001
#   -> Se encontraron 1 picos de error de PCA con multiplicador 13527.37.
# Procesando grupo 2/17: EM-E-002
#   -> Se encontraron 11 picos de error de PCA con multiplicador 13527.37.
# Procesando grupo 3/17: EM-E-004
#   -> Se encontraron 75 picos de error de PCA con multiplicador 13527.37.
# Procesando grupo 4/17: PD-E-006/3
#   -> Se encontraron 0 picos de error de PCA con multiplicador 13527.37.
# Procesando grupo 5/17: EM-E-003
#   -> Se encontraron 2 picos de error de PCA con multiplicador 13527.37.
# Procesando grupo 6/17: MV-E-027
#   -> Se encontraron 11 picos de error de PCA con multiplicador 13527.37.
# Procesando grupo 7/17: PD-E-006/1
#   -> Se encontraron 16 picos de error de PCA con multiplicador 13527.37.
# Procesando grupo 8/17: PD-E-006/2
# ...

# %%
# ==============================================================================
# Celda 6: Visualización de la Distribución del Error de Reconstrucción de PCA
# ==============================================================================
print("\n--- Visualizando la Distribución del Error de Reconstrucción de PCA ---")

if not all_reconstruction_errors.empty:
    plt.figure(figsize=(12, 6)) # Ajustar el tamaño para dos gráficos

    # Histograma del error de reconstrucción (Escala Logarítmica) - Usando Matplotlib
    plt.subplot(1, 2, 1) # 1 fila, 2 columnas, primer gráfico
    plt.hist(all_reconstruction_errors['reconstruction_error'], bins=50)
    plt.yscale('log') # Escala logarítmica en el eje y
    plt.title("Distribución del Error de Reconstrucción (Log Scale - Matplotlib)", fontsize=14)
    plt.xlabel("Error de Reconstrucción", fontsize=12)
    plt.ylabel("Frecuencia (Log Scale)", fontsize=12)

    # Boxplot del error de reconstrucción
    plt.subplot(1, 2, 2) # 1 fila, 2 columnas, segundo gráfico
    sns.boxplot(y=all_reconstruction_errors['reconstruction_error'])
    plt.title("Boxplot del Error de Reconstrucción (Log Scale)", fontsize=14)
    plt.ylabel("Error de Reconstrucción (Log Scale)", fontsize=12)
    plt.yscale('log') # Escala logarítmica en el eje y

    plt.tight_layout()
    plt.show()

    # Mostrar estadísticas descriptivas básicas
    print("\nEstadísticas descriptivas del Error de Reconstrucción:")
    display(all_reconstruction_errors['reconstruction_error'].describe())

else:
    print("El DataFrame 'all_reconstruction_errors' está vacío. Asegúrate de que la Celda 2 se ejecutó correctamente.")
# Out:
# --- Visualizando la Distribución del Error de Reconstrucción de PCA ---
# Estadísticas descriptivas del Error de Reconstrucción:
# count    7.556600e+04
# mean     4.511658e-03
# std      6.309459e-02
# min      0.000000e+00
# 25%      1.296722e-12
# 50%      2.566011e-06
# 75%      3.421353e-05
# max      2.800010e+00
# Name: reconstruction_error, dtype: float64

# %%
# ==============================================================================
# Celda 7: Análisis del Error de Reconstrucción por Categoría de Diagnóstico
# ==============================================================================
print("\n--- Analizando el Error de Reconstrucción por Categoría de Diagnóstico ---")

# Asegurarse de que los índices de all_reconstruction_errors y df_sensores coincidan
# Primero, alinear los DataFrames por índice (fecha)
# Usamos un join para mantener solo las fechas presentes en ambos
df_aligned = df_sensores.join(all_reconstruction_errors, how='inner')

if df_aligned.empty:
    print("Error: No se pudo alinear el DataFrame de diagnóstico con los errores de reconstrucción.")
else:
    # Visualización: Boxplot del Error de Reconstrucción por Categoría de Diagnóstico
    plt.figure(figsize=(12, 7))
    sns.boxplot(x='diagnostic_category', y='reconstruction_error', data=df_aligned, palette=color_map, order=category_order)
    plt.yscale('log') # Escala logarítmica en el eje y para visualizar mejor la distribución
    plt.title("Distribución del Error de Reconstrucción por Categoría de Diagnóstico", fontsize=16)
    plt.xlabel("Categoría de Diagnóstico", fontsize=12)
    plt.ylabel("Error de Reconstrucción (Escala Logarítmica)", fontsize=12)
    plt.xticks(rotation=0) # Rotar etiquetas del eje X si es necesario
    plt.tight_layout()
    plt.show()

    # Mostrar estadísticas descriptivas del Error de Reconstrucción por Categoría
    print("\nEstadísticas descriptivas del Error de Reconstrucción por Categoría de Diagnóstico:")
    display(df_aligned.groupby('diagnostic_category')['reconstruction_error'].describe())

    # Opcional: Visualizar histogramas separados por categoría (puede ser útil si hay muchas categorías)
    # print("\nVisualizando histogramas del Error de Reconstrucción por Categoría...")
    for category in category_order:
        df_cat_error = df_aligned[df_aligned['diagnostic_category'] == category]
        if not df_cat_error.empty:
            plt.figure(figsize=(8, 5))
            plt.hist(df_cat_error['reconstruction_error'], bins=50)
            plt.yscale('log')
            plt.title(f"Distribución del Error de Reconstrucción: {category}", fontsize=14)
            plt.xlabel("Error de Reconstrucción", fontsize=12)
            plt.ylabel("Frecuencia (Log Scale)", fontsize=12)
            plt.tight_layout()
            plt.show()
# Out:
# --- Analizando el Error de Reconstrucción por Categoría de Diagnóstico ---
# Estadísticas descriptivas del Error de Reconstrucción por Categoría de Diagnóstico:
#                           count      mean       std           min  \
# diagnostic_category
# Anomalía Estructural      405.0  0.104986  0.335749  1.676753e-06
# Anomalía Regional        5033.0  0.011488  0.060715  1.643460e-32
# Sensor Defectuoso      417698.0  0.002484  0.055385  0.000000e+00
# Sistema Normal        1080724.0  0.002492  0.043875  0.000000e+00
#
#                                25%           50%           75%       max
# diagnostic_category
# Anomalía Estructural  1.363030e-05  3.723784e-05  2.752450e-04  1.765773
# Anomalía Regional     3.493496e-06  2.230233e-05  7.514118e-05  0.723251
# Sensor Defectuoso     1.314768e-31  2.340369e-11  6.446086e-07  2.800010
# Sistema Normal        5.012554e-31  3.266400e-07  2.537918e-05  1.273585

# %%
# ==============================================================================
# Celda 8: Calcular el MAD del Error de Reconstrucción
# ==============================================================================
median_error = all_reconstruction_errors['reconstruction_error'].median()
mad_error = np.median(np.abs(all_reconstruction_errors['reconstruction_error'] - median_error))

print(f"Mediana del Error de Reconstrucción: {median_error}")
print(f"MAD del Error de Reconstrucción: {mad_error}")
# Out:
# Mediana del Error de Reconstrucción: 2.5660114022277597e-06
# MAD del Error de Reconstrucción: 2.5660114022277597e-06

# %%
# ==============================================================================
# Celda 9: Cálculo del mad_multiplier para diferentes percentiles
# ==============================================================================
print("\n--- Calculando mad_multiplier para diferentes percentiles del Error de Reconstrucción ---")

# Reutilizar la mediana y el MAD calculados en la celda 910ac703
# median_error = all_reconstruction_errors['reconstruction_error'].median() # Ya calculado
# mad_error = np.median(np.abs(all_reconstruction_errors['reconstruction_error'] - median_error)) # Ya calculado

# Obtener los valores de los percentiles del Error de Reconstrucción desde las estadísticas descriptivas
# Re-calcular las estadísticas descriptivas para asegurarnos de tener los percentiles exactos
error_stats = all_reconstruction_errors['reconstruction_error'].describe(percentiles=[.75, .90, .95, .99])

percentile_75 = error_stats['75%']
percentile_90 = error_stats['90%'] # Calcular el percentil 90
percentile_95 = error_stats['95%'] # Calcular el percentil 95
percentile_99 = error_stats['99%'] # Calcular el percentil 99

print(f"Percentil 75 del Error de Reconstrucción: {percentile_75}")
print(f"Percentil 90 del Error de Reconstrucción: {percentile_90}")
print(f"Percentil 95 del Error de Reconstrucción: {percentile_95}")
print(f"Percentil 99 del Error de Reconstrucción: {percentile_99}")

# La fórmula del umbral es: threshold_mad = median_error + mad_multiplier * mad_error
# Queremos encontrar mad_multiplier tal que threshold_mad sea igual a un percentil dado.
# Entonces: percentil_X = median_error + mad_multiplier * mad_error
# Despejando mad_multiplier: mad_multiplier = (percentil_X - median_error) / mad_error

# Asegurarse de que mad_error no sea cero para evitar división por cero
if mad_error == 0:
    print("\nEl MAD del Error de Reconstrucción es cero. No se puede calcular el mad_multiplier.")
else:
    mad_multiplier_75 = (percentile_75 - median_error) / mad_error
    mad_multiplier_90 = (percentile_90 - median_error) / mad_error
    mad_multiplier_95 = (percentile_95 - median_error) / mad_error
    mad_multiplier_99 = (percentile_99 - median_error) / mad_error

    print("\nValores de mad_multiplier para diferentes percentiles del Error de Reconstrucción:")
    print(f"Para umbral en Percentil 75: mad_multiplier = {mad_multiplier_75:.2f}")
    print(f"Para umbral en Percentil 90: mad_multiplier = {mad_multiplier_90:.2f}")
    print(f"Para umbral en Percentil 95: mad_multiplier = {mad_multiplier_95:.2f}")
    print(f"Para umbral en Percentil 99: mad_multiplier = {mad_multiplier_99:.2f}")

    print("\nConsideraciones:")
    print(f"- Un mad_multiplier de {mad_multiplier_75:.2f} establecería el umbral por encima del 75% de los errores.")
    print(f"- Un mad_multiplier de {mad_multiplier_90:.2f} establecería el umbral por encima del 90% de los errores.")
    print(f"- Un mad_multiplier de {mad_multiplier_95:.2f} establecería el umbral por encima del 95% de los errores.")
    print(f"- Un mad_multiplier de {mad_multiplier_99:.2f} establecería el umbral por encima del 99% de los errores.")
    print("\nSe pueden usar estos valores para ajustar la sensibilidad de la detección de anomalías temporales en la Celda 2.")
# Out:
# --- Calculando mad_multiplier para diferentes percentiles del Error de Reconstrucción ---
# Percentil 75 del Error de Reconstrucción: 3.4213534101051546e-05
# Percentil 90 del Error de Reconstrucción: 0.00012192451832949843
# Percentil 95 del Error de Reconstrucción: 0.0006918548298503783
# Percentil 99 del Error de Reconstrucción: 0.034713947452670806
#
# Valores de mad_multiplier para diferentes percentiles del Error de Reconstrucción:
# Para umbral en Percentil 75: mad_multiplier = 12.33
# Para umbral en Percentil 90: mad_multiplier = 46.52
# Para umbral en Percentil 95: mad_multiplier = 268.62
# Para umbral en Percentil 99: mad_multiplier = 13527.37
#
# Consideraciones:
# - Un mad_multiplier de 12.33 establecería el umbral por encima del 75% de los errores.
# - Un mad_multiplier de 46.52 establecería el umbral por encima del 90% de los errores.
# - Un mad_multiplier de 268.62 establecería el umbral por encima del 95% de los errores.
# ...
